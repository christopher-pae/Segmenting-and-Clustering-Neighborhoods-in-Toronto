# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
r=requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# %%
soup=BeautifulSoup(r.text,'html.parser')

# %%
postal_code=[]
borough=[]
neighborhood=[]
for rows in soup.find('table').find_all("tr"):
    rows=rows.find_all("td")
    if(len(rows)>0):
        postal_code.append(rows[0].text.rstrip('\n'))
        borough.append(rows[1].text.rstrip('\n'))
        neighborhood.append(rows[2].text.rstrip('\n'))

# %%
toronto_df=pd.DataFrame({'PostalCode':postal_code,'Borough':borough,'Neighborhood':neighborhood})
toronto_df.head()
# Out:
#   PostalCode           Borough               Neighborhood
# 0        M1A      Not assigned               Not assigned
# 1        M2A      Not assigned               Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
toronto_df=pd.DataFrame({'PostalCode':postal_code,'Borough':borough,'Neighborhood':neighborhood})
toronto_df.head()
# Out:
#   PostalCode           Borough               Neighborhood
# 0        M1A      Not assigned               Not assigned
# 1        M2A      Not assigned               Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
toronto_df=toronto_df.groupby(['PostalCode','Borough'],as_index=False).agg(lambda x: ",".join(x))
toronto_df.head()
# Out:
#   PostalCode       Borough                            Neighborhood
# 0        M1A  Not assigned                            Not assigned
# 1        M1B   Scarborough                          Malvern, Rouge
# 2        M1C   Scarborough  Rouge Hill, Port Union, Highland Creek
# 3        M1E   Scarborough       Guildwood, Morningside, West Hill
# 4        M1G   Scarborough                                  Woburn

# %%
for i,j in enumerate(toronto_df['Borough']):
    if(toronto_df.loc[i,'Neighborhood']=='Not assigned'):
        toronto_df.loc[i,'Neighborhood']=j

# %%
toronto_df.shape
# Out:
# (180, 3)

# %%
from geopy.geocoders import Nominatim

# %%
geo_data=pd.read_csv(r'C:\Users\chris\Desktop\Capstone Project\Week 3\Geospatial_Coordinates.csv',)
geo_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-98c667a6c668> in <module>
# ----> 1 geo_data=pd.read_csv(r'C:\Users\chris\Desktop\Capstone Project\Week 3\Geospatial_Coordinates.csv',)
#       2 geo_data.head()
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'C:\\Users\\chris\\Desktop\\Capstone Project\\Week 3\\Geospatial_Coordinates.csv' does not exist: b'C:\\Users\\chris\\Desktop\\Capstone Project\\Week 3\\Geospatial_Coordinates.csv'

# %%
geo_data.rename(columns={'Postal Code':'PostalCode'},inplace=True)
geo_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4167d11ba6cf> in <module>
# ----> 1 geo_data.rename(columns={'Postal Code':'PostalCode'},inplace=True)
#       2 geo_data.head()
#
# NameError: name 'geo_data' is not defined

# %%
toronto_df=toronto_df.merge(geo_data,on="PostalCode",how='left')
toronto_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5f87baabcc61> in <module>
# ----> 1 toronto_df=toronto_df.merge(geo_data,on="PostalCode",how='left')
#       2 toronto_df.head()
#
# NameError: name 'geo_data' is not defined

# %%
test_list = ["M5G", "M2H", "M4B", "M1J", "M4G", "M4M", "M1R", "M9V", "M9L", "M5V", "M1B", "M5A"]
test=pd.DataFrame()
for i in test_list:
    test=test.append(toronto_df[toronto_df['PostalCode']==i])
test
# Out:
#     PostalCode           Borough  \
# 84         M5G  Downtown Toronto
# 25         M2H        North York
# 61         M4B         East York
# 6          M1J       Scarborough
# 64         M4G         East York
# 69         M4M      East Toronto
# 12         M1R       Scarborough
# 175        M9V         Etobicoke
# 168        M9L        North York
# 95         M5V  Downtown Toronto
# 1          M1B       Scarborough
# 80         M5A  Downtown Toronto
#
#                                           Neighborhood
# 84                                  Central Bay Street
# 25                                   Hillcrest Village
# 61                     Parkview Hill, Woodbine Gardens
# 6                                  Scarborough Village
# 64                                             Leaside
# 69                                     Studio District
# 12                                   Wexford, Maryvale
# 175  South Steeles, Silverstone, Humbergate, Jamest...
# 168                                      Humber Summit
# 95   CN Tower, King and Spadina, Railway Lands, Har...
# 1                                       Malvern, Rouge
# 80                           Regent Park, Harbourfront
